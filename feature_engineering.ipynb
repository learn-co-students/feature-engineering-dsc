# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split,KFold,cross_validate
from sklearn.preprocessing import PolynomialFeatures,StandardScaler

from sklearn.linear_model import LinearRegression
from sklearn.datasets import california_housing

# %%
data = california_housing.fetch_california_housing()

# %%
X = pd.DataFrame(data['data'],columns=data['feature_names'])
y = pd.DataFrame(data['target'])

# %%
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %% [markdown]
# # Feature Engineering

# %%
poly = PolynomialFeatures(2)

# %%
poly.fit(X);

# %%
X_poly = poly.transform(X)

# %%
X_poly.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-e9f9f81e5667> in <module>
# ----> 1 X_poly.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
X_poly
# Out:
# array([[ 1.00000000e+00,  8.32520000e+00,  4.10000000e+01, ...,
#          1.43489440e+03, -4.63007240e+03,  1.49401729e+04],
#        [ 1.00000000e+00,  8.30140000e+00,  2.10000000e+01, ...,
#          1.43337960e+03, -4.62724920e+03,  1.49377284e+04],
#        [ 1.00000000e+00,  7.25740000e+00,  5.20000000e+01, ...,
#          1.43262250e+03, -4.62678400e+03,  1.49426176e+04],
#        ...,
#        [ 1.00000000e+00,  1.70000000e+00,  1.70000000e+01, ...,
#          1.55472490e+03, -4.77970460e+03,  1.46942884e+04],
#        [ 1.00000000e+00,  1.86720000e+00,  1.80000000e+01, ...,
#          1.55472490e+03, -4.78364760e+03,  1.47185424e+04],
#        [ 1.00000000e+00,  2.38860000e+00,  1.60000000e+01, ...,
#          1.54999690e+03, -4.77321880e+03,  1.46991376e+04]])

# %% [markdown]
# ### Bringing back to pandas

# %%
X_poly = pd.DataFrame(X_poly)
X_poly.head()
# Out:
#     0       1     2         3         4       5         6      7       8   \
# 0  1.0  8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1  1.0  8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2  1.0  7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3  1.0  5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4  1.0  3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25
#
#           9   ...         35           36        37         38        39  \
# 0  69.308955  ...   103684.0   822.888889  12197.36  -39358.06  6.530864
# 1  68.913242  ...  5764801.0  5065.730228  90901.86 -293450.22  4.451433
# 2  52.669855  ...   246016.0  1389.920904  18773.60  -60631.04  7.852660
# 3  31.844578  ...   311364.0  1421.753425  21120.30  -68215.50  6.492025
# 4  14.793254  ...   319225.0  1232.528958  21385.25  -69071.25  4.758799
#
#            40          41         42         43          44
# 0   96.804444 -312.365556  1434.8944 -4630.0724  14940.1729
# 1   79.878612 -257.864868  1433.3796 -4627.2492  14937.7284
# 2  106.065537 -342.548249  1432.6225 -4626.7840  14942.6176
# 3   96.439726 -311.486301  1432.6225 -4627.1625  14945.0625
# 4   82.568533 -266.684363  1432.6225 -4627.1625  14945.0625
#
# [5 rows x 45 columns]

# %% [markdown]
# ### Recovering the column names

# %%
cols = poly.get_feature_names(X.columns)
cols[:5]
# Out:
# ['1', 'MedInc', 'HouseAge', 'AveRooms', 'AveBedrms']

# %%
X_poly.columns = cols
X_poly.head()
# Out:
#      1  MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  1.0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  1.0  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  1.0  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  1.0  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  1.0  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude   MedInc^2  ...  Population^2  Population AveOccup  \
# 0    -122.23  69.308955  ...      103684.0           822.888889
# 1    -122.22  68.913242  ...     5764801.0          5065.730228
# 2    -122.24  52.669855  ...      246016.0          1389.920904
# 3    -122.25  31.844578  ...      311364.0          1421.753425
# 4    -122.25  14.793254  ...      319225.0          1232.528958
#
#    Population Latitude  Population Longitude  AveOccup^2  AveOccup Latitude  \
# 0             12197.36             -39358.06    6.530864          96.804444
# 1             90901.86            -293450.22    4.451433          79.878612
# 2             18773.60             -60631.04    7.852660         106.065537
# 3             21120.30             -68215.50    6.492025          96.439726
# 4             21385.25             -69071.25    4.758799          82.568533
#
#    AveOccup Longitude  Latitude^2  Latitude Longitude  Longitude^2
# 0         -312.365556   1434.8944          -4630.0724   14940.1729
# 1         -257.864868   1433.3796          -4627.2492   14937.7284
# 2         -342.548249   1432.6225          -4626.7840   14942.6176
# 3         -311.486301   1432.6225          -4627.1625   14945.0625
# 4         -266.684363   1432.6225          -4627.1625   14945.0625
#
# [5 rows x 45 columns]

# %%
poly3 = PolynomialFeatures(3)
X_poly3 = poly3.fit_transform(X)
X_poly3 = pd.DataFrame(X_poly3,columns = poly3.get_feature_names(X.columns))
X_poly3.head()
# Out:
#      1  MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  1.0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  1.0  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  1.0  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  1.0  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  1.0  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude   MedInc^2  ...  AveOccup^3  AveOccup^2 Latitude  \
# 0    -122.23  69.308955  ...   16.689986           247.389136
# 1    -122.22  68.913242  ...    9.391819           168.531236
# 2    -122.24  52.669855  ...   22.005195           297.223199
# 3    -122.25  31.844578  ...   16.541323           245.723138
# 4    -122.25  14.793254  ...   10.381164           180.120545
#
#    AveOccup^2 Longitude  AveOccup Latitude^2  AveOccup Latitude Longitude  \
# 0           -798.267531          3666.952356                -11832.407244
# 1           -544.054085          3024.204235                 -9762.763910
# 2           -959.909216          4014.580565                -12965.451209
# 3           -793.650028          3650.243630                -11789.756507
# 4           -581.763186          3125.218967                -10094.003137
#
#    AveOccup Longitude^2    Latitude^3  Latitude^2 Longitude  \
# 0          38180.441856  54353.799872        -175387.142512
# 1          31516.244190  54267.751656        -175187.654712
# 2          41873.097907  54224.761625        -175123.774400
# 3          38079.200342  54224.761625        -175138.100625
# 4          32602.163369  54224.761625        -175138.100625
#
#    Latitude Longitude^2   Longitude^3
# 0         565933.749452 -1.826137e+06
# 1         565542.397224 -1.825689e+06
# 2         565578.076160 -1.826586e+06
# 3         565670.615625 -1.827034e+06
# 4         565670.615625 -1.827034e+06
#
# [5 rows x 165 columns]

# %% [markdown]
# # Train / Validation / Test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_poly,y,test_size=1000, random_state=42)
X_train_v, X_val, y_train_v, y_val = train_test_split(X_train,y_train,test_size=1000, random_state=123)

# %%
scaler = StandardScaler()

# %%
X_train_v.head()
# Out:
#          1  MedInc  HouseAge   AveRooms  AveBedrms  Population  AveOccup  \
# 17477  1.0  3.8056      21.0   5.881517   1.175355       746.0  3.535545
# 12220  1.0  5.2066       4.0  10.500000   1.445652       311.0  3.380435
# 1764   1.0  3.0313      45.0   4.249330   0.882038       981.0  2.630027
# 12869  1.0  3.9318       7.0   5.338479   1.030871      2857.0  3.149945
# 20086  1.0  2.5170      23.0   5.101604   1.024064       984.0  2.631016
#
#        Latitude  Longitude   MedInc^2  ...  Population^2  Population AveOccup  \
# 17477     34.47    -120.05  14.482591  ...      556516.0          2637.516588
# 12220     33.51    -117.32  27.108684  ...       96721.0          1051.315217
# 1764      37.95    -122.33   9.188780  ...      962361.0          2580.056300
# 12869     38.71    -121.38  15.459051  ...     8162449.0          8999.392503
# 20086     37.99    -120.30   6.335289  ...      968256.0          2588.919786
#
#        Population Latitude  Population Longitude  AveOccup^2  \
# 17477             25714.62             -89557.30   12.500079
# 12220             10421.61             -36486.52   11.427339
# 1764              37228.95            -120005.73    6.917041
# 12869            110594.47            -346782.66    9.922153
# 20086             37382.16            -118375.20    6.922245
#
#        AveOccup Latitude  AveOccup Longitude  Latitude^2  Latitude Longitude  \
# 17477         121.870237         -424.442180   1188.1809          -4138.1235
# 12220         113.278370         -396.592609   1122.9201          -3931.3932
# 1764           99.809517         -321.731180   1440.2025          -4642.4235
# 12869         121.934366         -382.340309   1498.4641          -4698.6198
# 20086          99.952299         -316.511230   1443.2401          -4570.1970
#
#        Longitude^2
# 17477   14412.0025
# 12220   13763.9824
# 1764    14964.6289
# 12869   14733.1044
# 20086   14472.0900
#
# [5 rows x 45 columns]

# %%
scaler.fit(X_train_v)

X_train_v = scaler.transform(X_train_v)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %%
X_train_v.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-50312d622d56> in <module>
# ----> 1 X_train_v.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
X_train_v
# Out:
# array([[ 0.        , -0.03184148, -0.60643492, ..., -0.55903237,
#          0.3919493 ,  0.22921982],
#        [ 0.        ,  0.71034785, -1.95523152, ..., -0.98168359,
#          1.03006446, -1.11933583],
#        [ 0.        , -0.44203219,  1.29774851, ...,  1.07314556,
#         -1.16467534,  1.37925738],
#        ...,
#        [ 0.        ,  0.23669226,  1.85313534, ...,  0.98976849,
#         -1.08415775,  1.30801756],
#        [ 0.        , -0.89455048, -0.84445785, ...,  0.34566525,
#         -0.32905312,  0.18926053],
#        [ 0.        ,  0.78260668, -0.92379882, ..., -0.89898136,
#          0.89572557, -0.81088389]])

# %%
X_train_v = pd.DataFrame(X_train_v,columns = poly.get_feature_names(X.columns))
X_train_v.head()
# Out:
#      1    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0  0.0 -0.031841 -0.606435  0.178642   0.160661   -0.595176  0.041127
# 1  0.0  0.710348 -1.955232  2.009597   0.717012   -0.975745  0.026930
# 2  0.0 -0.442032  1.297749 -0.468423  -0.443074   -0.389582 -0.041752
# 3  0.0  0.035014 -1.717209 -0.036640  -0.136730    1.251674  0.005834
# 4  0.0 -0.714486 -0.447753 -0.130547  -0.150741   -0.386957 -0.041662
#
#    Latitude  Longitude  MedInc^2  ...  Population^2  Population AveOccup  \
# 0 -0.545903  -0.237692 -0.186257  ...     -0.201979            -0.035212
# 1 -0.995294   1.124305  0.398111  ...     -0.235333            -0.056218
# 2  1.083141  -1.375184 -0.431269  ...     -0.172538            -0.035973
# 3  1.438909  -0.901229 -0.141064  ...      0.349765             0.049040
# 4  1.101866  -0.362417 -0.563336  ...     -0.172111            -0.035855
#
#    Population Latitude  Population Longitude  AveOccup^2  AveOccup Latitude  \
# 0            -0.618676              0.593722   -0.009883           0.028188
# 1            -0.999334              0.983844   -0.009974           0.007664
# 2            -0.332074              0.369896   -0.010357          -0.024510
# 3             1.494065             -1.297135   -0.010102           0.028341
# 4            -0.328260              0.381882   -0.010357          -0.024169
#
#    AveOccup Longitude  Latitude^2  Latitude Longitude  Longitude^2
# 0           -0.041747   -0.559032            0.391949     0.229220
# 1           -0.020776   -0.981684            1.030064    -1.119336
# 2            0.035597    1.073146           -1.164675     1.379257
# 3           -0.010043    1.450468           -1.338137     0.897446
# 4            0.039528    1.092818           -0.941734     0.354264
#
# [5 rows x 45 columns]

# %% [markdown]
# # Fit and evaluate model

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(X_train_v,y_train_v);

# %%
lin_reg.score(X_train_v,y_train_v)
# Out:
# 0.6829105379055355

# %%
lin_reg.score(X_val,y_val)
# Out:
# 0.678956128839695

# %% [markdown]
# # Final check on the Test dataset

# %%
X_train = scaler.transform(X_train)
lin_reg.fit(X_train,y_train);
lin_reg.score(X_test,y_test)
